# %%
import pandas as pd

# %%
panel=pd.read_csv('https://github.com/ArtKTP/Siametrics-Pre-interview-Assignment/raw/master/result/panel.csv')
panel.head(100)

# %%
panel.describe()
# Out:
#            person_id          year       id_s_fr           age        female  \
# count   29594.000000  29594.000000  1.285900e+04  14556.000000  14556.000000
# mean    79066.673143   2352.273637  3.039191e+09     43.597497      0.747835
# std     36609.865871   1607.200362  1.489746e+09     12.311148      0.434121
# min         2.000000   2012.000000  1.000110e+09      0.000000      0.000000
# 25%     48098.000000   2013.000000  3.000010e+09     33.000000      0.000000
# 50%     79425.000000   2015.000000  3.000010e+09     44.000000      1.000000
# 75%    113976.000000   2016.000000  3.000010e+09     53.000000      1.000000
# max    134862.000000   9999.000000  6.206069e+10     86.000000      1.000000
#
#              perf_a       perf_b        perf_c  avg_absences
# count  13077.000000  3153.000000  13376.000000  19966.000000
# mean       0.004199    -0.000463     -0.014168      5.703033
# std        0.999235     1.003033      0.868966      3.602196
# ...

# %%
panel.describe(include='all')
# Out:
#             person_id          year       id_s_fr           age        female  \
# count    29594.000000  29594.000000  1.285900e+04  14556.000000  14556.000000
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     79066.673143   2352.273637  3.039191e+09     43.597497      0.747835
# std      36609.865871   1607.200362  1.489746e+09     12.311148      0.434121
# min          2.000000   2012.000000  1.000110e+09      0.000000      0.000000
# 25%      48098.000000   2013.000000  3.000010e+09     33.000000      0.000000
# 50%      79425.000000   2015.000000  3.000010e+09     44.000000      1.000000
# 75%     113976.000000   2016.000000  3.000010e+09     53.000000      1.000000
# max     134862.000000   9999.000000  6.206069e+10     86.000000      1.000000
#
# ...

# %%
#Top three issues with the data
1. Discontinued follow-up eg. person_id = 2  that have id_s_fr = 3000010175 in 2012 But not have id_s_fr in 2013 
2. Values outside of domain range eg. the data being collected really is in the range 2012-2017 but a year have 9999 in max value.
3. Unavailable values during data entry(dummy values or null) eg. perf_a  = Null, perf_b = Null, perf_c = Null, avg_absences = Null
